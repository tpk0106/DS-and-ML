# %% [markdown]
# ## Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); # to remove above empty brackets use semicolon at the end

# %%
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
# 1st method
fig = plt.figure()
ax = fig.add_subplot() # add some axes
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method
fig, ax = plt.subplots()
ax.plot(x,y) # add some data
plt.show()

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# 1 prepare data

x = [1,2,3,4]
y = [11,22,33,44]

#2 setup plot

fig,ax = plt.subplots(figsize=[10,10]) # width,height

# 3 plaot data

ax.plot(x,y)

#customize plot

ax.set(title="Simple plot", xlabel="x-axis",ylabel="y-axis")

# save and show ( save the whole figure)
fig.savefig("sample-plot.png")
#plt.show()

# %% [markdown]
# ## Making figures with NumPy arrays
# we want
# * line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * subplot

# %%
import numpy as np

# %%
# creat some data
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data and create line plot
fig, ax = plt.subplots()
ax.plot(x,x**2)
plt.show()

# %%
# use same data to create scatter plot
fig,ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))
plt.show()

# %%
# Make a plot from dictionary
nut_butter_prices = {"Alomond Butter":10,
                     "Peanut butter":8,
                     "Cashew butter": 18}

fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Thusith's Nut Butter Store",ylabel="Price")
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Thusith's Nut Butter Store",xlabel="Price")
plt.show()

# %%
# make some data for histogram and plot 
xp = np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(xp)
plt.show()

# %% [markdown]
# ## two options for subplots

# %%
# subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2, ncols=2,figsize=(10,5))
# plot to each different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.rand(1000))
plt.show()

# %%
# subplot option 2 
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
# plot to each different index
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1,1].hist(np.random.rand(100))
plt.show()

# %% [markdown]
# ## plotting form pandas dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#make a DataDrame

car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2025",periods=1000))
ts = ts.cumsum()
ts
# Out:
# 2025-01-01    0.389546
# 2025-01-02    1.093615
# 2025-01-03    3.183106
# 2025-01-04    2.519183
# 2025-01-05    2.207699
#                 ...
# 2027-09-23   -4.361667
# 2027-09-24   -3.825177
# 2027-09-25   -4.206318
# 2027-09-26   -4.085731
# 2027-09-27   -5.096001
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].replace("[\$\.|,]","",regex=True)
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
# remove last two zeros
# method 1
## car_sales["Price"] =  (car_sales["Price"]).astype(int)/100
#method 2 
car_sales["Price"] =  car_sales["Price"].str[:-2]
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2025",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2025-01-01
# 1   Honda    Red          87899      4   5000 2025-01-02
# 2  Toyota   Blue          32549      3   7000 2025-01-03
# 3     BMW  Black          11179      5  22000 2025-01-04
# 4  Nissan  White         213095      4   3500 2025-01-05
# 5  Toyota  Green          99213      4   4500 2025-01-06
# 6   Honda   Blue          45698      4   7500 2025-01-07
# 7   Honda   Blue          54738      4   7000 2025-01-08
# 8  Toyota  White          60000      4   6250 2025-01-09
# 9  Nissan  White          31600      4   9700 2025-01-10

# %%
car_sales["Total Sales"] = (car_sales["Price"]).astype(int).cumsum()

# %%
type(car_sales["Price"][0])
#type((car_sales["Price"][0]).astype(int))
# Out:
# str

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
#plot total sales
car_sales.plot(x="Sale Date",y="Total Sales")
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
# convert price column to numeric if needed
# car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
plt.show()

# %%
x = np.random.rand(10,4)

# tuen it into data frame
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.298267  0.717041  0.444765  0.288028
# 1  0.258624  0.743297  0.221139  0.810204
# 2  0.382074  0.761124  0.690196  0.256273
# 3  0.694489  0.450372  0.579353  0.038751
# 4  0.371781  0.394751  0.917163  0.079079
# 5  0.775824  0.846097  0.068555  0.693203
# 6  0.976902  0.114827  0.944372  0.565492
# 7  0.183170  0.885967  0.761450  0.644171
# 8  0.062962  0.455388  0.044195  0.114871
# 9  0.990073  0.247498  0.265115  0.647419

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
# another way
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a hist of age

heart_disease["age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,40),subplots=True);

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target",figsize=(10,6))
plt.show()

# %%
# oo method mixed with pyplot method
fix,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax)
# ax.set_xlim([45,100])
plt.show()

# %%
# oo method from scratch
fig,ax = plt.subplots(figsize=(10,6))
#plot the data
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
# plt.show()
# customize 
ax.set(title="Heart Disease and Cholestorol Levels",xlabel="age",ylabel="Cholestorol Levels")

# add a legend
ax.legend(*scatter.legend_elements(),title="Target")
# add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--")
plt.show()

# %%
# subplot of chol, age and thalach
fig,(ax0,ax1) = plt.subplots(nrows=2,ncols=1, figsize=(10,10),sharex=True)

# add data to ax0
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],
                      cmap="winter"); # color the graph

#customize ax0
ax0.set(title="Heart Disease and Cholestorol Levels",ylabel="Cholestorol Levels")

# change the x axis limits
ax0.set_xlim([50,80])

# add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="target")

# add a mean line
ax0.axhline(over_50["chol"].mean(),ls="--")

# thalach column

# add data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],
                       cmap="winter")  # color the graph

#customize ax1
ax1.set(title="Heart Disease and Thalach",xlabel="Age",ylabel="Max Heart Rate")

ax1.set_xlim([50,80])  # xaxis
ax1.set_ylim([85,200]) # y axis

# add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="target")

# add a mean line
ax1.axhline(over_50["thalach"].mean(),ls="--")


# add a  title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")

fig.savefig("heart-disease-analysis.png")

# %% [markdown]
# ## Customizing matplotlib plots and getting stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
#car_sales = pd.read_csv("car-sales.csv")
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-whitegrid")
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-darkgrid")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)",y="Make",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Make'>

# %%
plt.style.use("ggplot")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
# create some data
x = np.random.randn(10,4)
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.328175 -2.289917 -0.426094 -0.535427
# 1 -0.742307 -0.453648 -0.731658  0.300397
# 2  0.030976 -3.166864  1.325335  0.661936
# 3  0.282761  0.242964 -0.352196 -0.922660
# 4 -0.801311 -0.208321 -0.846537  2.155515
# 5 -0.558445 -1.028019 -0.332428  0.516074
# 6 -0.849030 -0.053057  0.667562 -1.484024
# 7 -0.481837  0.654747  0.292345 -0.375000
# 8 -0.056299  0.280379 -0.774889  0.361526
# 9 -0.198495  0.948614 -1.472314 -0.299594

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# customize our plot with set method
ax=df.plot(kind="bar")
# add some labels and title
ax.set(title="Random bar graph from dataframe",xlabel="Row Number",ylabel="Randome Number")
S
# make the legend visible
ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-v0_8-whitegrid") # set the color style
# oo method from scratch
fig,ax = plt.subplots(figsize=(10,6))
#plot the data
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter") # this changes the color scheme
# plt.show()
# customize 
ax.set(title="Heart Disease and Cholestorol Levels",xlabel="age",ylabel="Cholestorol Levels")

# add a legend
ax.legend(*scatter.legend_elements(),title="Target")
# add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--")

# customizing y and x axis limitaion
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold")
plt.show()
