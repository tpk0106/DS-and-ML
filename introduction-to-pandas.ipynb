# %%
import pandas as pd

# %%
## 2 main data types
series = pd.Series(["BMW","Honda","Toyota"])

# %%
series
# Out:
# 0       BMW
# 1     Honda
# 2    Toyota
# dtype: object

# %%
# series 1-dimentional

# %%
colors = pd.Series(["Red","Green","Blue","Purple"])
colors
# Out:
# 0       Red
# 1     Green
# 2      Blue
# 3    Purple
# dtype: object

# %%
# DataFrame is 2-dimentional (2nd datatype)
cardf = pd.DataFrame({"Car Make":series, "Color":colors})

# %%
cardf
# Out:
#   Car Make   Color
# 0      BMW     Red
# 1    Honda   Green
# 2   Toyota    Blue
# 3      NaN  Purple

# %%
# import data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# df_electricity = pd.read_csv("MyUsageData_20-08-2025.csv")
# df_electricity

# %%
# exporting dataframe 
car_sales.to_csv("exported-car-sales.csv",index=False) ## index=False to remove index column when exporting

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# In some of the lectures, you'll notice .csv files being imported from file using something like:
#
# heart_disease = pd.read_csv("data/heart-disease.csv")
#
# This is helpful if you have the data downloaded to your computer or in the same directory as your notebook.
# But if you don't, another great feature of pandas is being able to import .csv files directly from a URL.
# For example, for the heart-disease.csv file, using the read_csv() function you can directly import it using the URL from the course GitHub repo:
#
# heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
#
# Note: If you're using a link from GitHub, make sure it's in the "raw" format, by clicking the raw button.

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales["Doors"].mean()
# Out:
# np.float64(4.0)

# %%
car_sales.max()
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)       213095
# Doors                    5
# Price            $9,700.00
# dtype: object

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and iloc
animals = pd.Series(["horse","cow","cat","dog","bird"],index=[3,7,3,5,9])
animals
# Out:
# 3    horse
# 7      cow
# 3      cat
# 5      dog
# 9     bird
# dtype: object

# %%
# .loc refers to index
animals.loc[3]
# Out:
# 3    horse
# 3      cat
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                          BMW
# Colour                      Black
# Odometer (KM)            6986.875
# Doors                           5
# Price                  $22,000.00
# Seats                         5.0
# Fuel for 100KM                7.0
# Total fuel used (L)        782.53
# Number of wheels                4
# Passed road Safety         Passed
# Name: 3, dtype: object

# %%
# iloc refers to actual position
animals.iloc[3]
# Out:
# 'dog'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 3    horse
# 7      cow
# 3      cat
# dtype: object

# %%
car_sales.loc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.iloc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] == "Toyota"
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Make, dtype: bool

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# groupby
cs = car_sales.groupby(["Make","Colour"])["Doors"].mean()
cs
# Out:
# Make    Colour
# BMW     Black     5.0
# Honda   Blue      4.0
#         Red       4.0
# Nissan  White     4.0
# Toyota  Blue      3.0
#         Green     4.0
#         White     4.0
# Name: Doors, dtype: float64

# %%
# group by make and color where make is "Toyota"
cs1 = car_sales[car_sales["Make"] == "Toyota"].groupby(["Make","Colour"])["Doors"].mean()
cs1
# Out:
# Make    Colour
# Toyota  Blue      3.0
#         Green     4.0
#         White     4.0
# Name: Doors, dtype: float64

# %%
# %matplotlib inlineM
import matplotlib.pyplot as plt
car_sales["Odometer (KM)"].plot()
plt.show()

# %%
import matplotlib.pyplot as plt
car_sales["Odometer (KM)"].hist()
plt.show()

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"] =car_sales["Price"].replace('\\D','',regex=True).astype(int)
# car_sales["Price"].replace('\\D','',regex=True).astype(int).plot() # another way

## need to test this way
# car_sales["Price"] = car_sales["Price"].str.replace('[\\$\\,\\.]','').astype(int) 

# double slash need to use for escape
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# price wise
car_sales["Price"].plot()
plt.show()

# %%
car_sales.plot()
plt.show()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna(inplace=False)
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# column from series
seat_columns = pd.Series([5,5,5,5,5])

# New column called seats

car_sales["Seats"] = seat_columns
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(value=5,inplace=True)
# Out:
# C:\Users\thusi\AppData\Local\Temp\ipykernel_4828\699572019.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(value=5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
# column from python list
fuel_economy = [3.4,7.5,4,7,9.2,11.2,11,2,6,4.0]

car_sales["Fuel for 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"] /100 * car_sales["Fuel for 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0
#
#    Total fuel used  Total fuel used (L)
# 0         5101.462             5101.462
# 1         6592.425             6592.425
# ...

# %%
# create a column from single value
car_sales["Number of wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0         5101.462             5101.462                 4
# ...

# %%
car_sales.drop("Total fuel used",axis=1,inplace=True)

# %%
car_sales["Passed road Safety"] = "Passed" if True else "Failed"
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels Passed road Safety
# 0         5101.462             5101.462                 4             Passed
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0
#
#    Total fuel used (L)  Number of wheels Passed road Safety
# 0             5101.462                 4             Passed
# ...

# %%
car_sales.to_csv("car-sales-with-added-columns")

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 1   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 0  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 8  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 7   Honda   Blue          54738      4   $7,000.00    5.0             2.0
#
#    Total fuel used (L)  Number of wheels Passed road Safety
# 9             1264.000                 4             Passed
# ...

# %%
# only present 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel for 100KM  \
# 4  Nissan  White         213095      4  $3,500.00    5.0             9.2
# 7   Honda   Blue          54738      4  $7,000.00    5.0             2.0
#
#    Total fuel used (L)  Number of wheels Passed road Safety
# 4             19604.74                 4             Passed
# 7              1094.76                 4             Passed

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0      9  Nissan  White          31600      4   $9,700.00    5.0
# 1      5  Toyota  Green          99213      4   $4,500.00    5.0
# 2      6   Honda   Blue          45698      4   $7,500.00    5.0
# 3      1   Honda    Red          87899      4   $5,000.00    5.0
# 4      0  Toyota  White         150043      4   $4,000.00    5.0
# 5      8  Toyota  White          60000      4   $6,250.00    5.0
# 6      2  Toyota   Blue          32549      3   $7,000.00    5.0
# 7      3     BMW  Black          11179      5  $22,000.00    5.0
# 8      4  Nissan  White         213095      4   $3,500.00    5.0
# 9      7   Honda   Blue          54738      4   $7,000.00    5.0
#
#    Fuel for 100KM  Total fuel used (L)  Number of wheels Passed road Safety
# 0             4.0             1264.000                 4             Passed
# 1            11.2            11111.856                 4             Passed
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffledS
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Nissan  White          31600      4   $9,700.00    5.0             4.0
# 1  Toyota  Green          99213      4   $4,500.00    5.0            11.2
# 2   Honda   Blue          45698      4   $7,500.00    5.0            11.0
# 3   Honda    Red          87899      4   $5,000.00    5.0             7.5
# 4  Toyota  White         150043      4   $4,000.00    5.0             3.4
# 5  Toyota  White          60000      4   $6,250.00    5.0             6.0
# 6  Toyota   Blue          32549      3   $7,000.00    5.0             4.0
# 7     BMW  Black          11179      5  $22,000.00    5.0             7.0
# 8  Nissan  White         213095      4   $3,500.00    5.0             9.2
# 9   Honda   Blue          54738      4   $7,000.00    5.0             2.0
#
#    Total fuel used (L)  Number of wheels Passed road Safety
# 0             1264.000                 4             Passed
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel for 100KM  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0             3.4
# 1   Honda    Red      54936.875      4   $5,000.00    5.0             7.5
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0             4.0
# 3     BMW  Black       6986.875      5  $22,000.00    5.0             7.0
# 4  Nissan  White     133184.375      4   $3,500.00    5.0             9.2
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0            11.2
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0            11.0
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0             2.0
# 8  Toyota  White      37500.000      4   $6,250.00    5.0             6.0
# 9  Nissan  White      19750.000      4   $9,700.00    5.0             4.0
#
#    Total fuel used (L)  Number of wheels Passed road Safety
# 0             5101.462                 4             Passed
# ...
